# %%
import checkout_automation

# %%
test_html = str(open("../test-extension.html").read())
test_user_data = """

name: John Doe
email: john123@gmail.com
phone: 123-456-7890
address: 123 Main St, Springfield, IL
city: Springfield
state: IL
zip: 62701
country: USA
credit_card_number: 4111 1111 1111 1111
credit_card_expiry: 12/25
credit_card_cvv: 123
# This is a test user data string that simulates the data that would be filled in during a checkout process.
"""
checkout_automation.THINKING_BUDGET = 0
a = checkout_automation.automate_checkout_form(test_html, test_user_data, verbose=True, fast=False, depth = 1, min_size_for_chunking=1000, max_chunks=4)
# Out:
# 🚀 Starting checkout form automation...
# ...
# Not using fast mode - limiting to 1 chunk for higher quality processing
# 🔍 Element detection summary:
#    - Total elements: 16
#    - Input-type elements: 12
#    - Button-type elements: 3
# HTML size: 8.3 KB
# Chunking strategy: Disabled
# Using single-pass processing...
# Validating user data and form mapping...
# 💾 Results saved to: form_filling_actions.json
# 🎉 Checkout form automation completed!
# ...

# %%
from process_checkout import process_checkout_page
import json

# Sample HTML content for testing
# You can replace this with more complex HTML or load from a file
sample_html = str(open("../test-extension.html").read())

# Default user data (can be customized or loaded)
test_user_data = """
name: Jane Doe
email: jane.doe@example.com
phone: +1-555-0199
address: 456 Oak St
city: Anytown
state: CA
zip: 90210
country: United States
card_number: 4222222222222222
card_expiry: 01/26
card_cvv: 456
"""

print("🧪 Running test for process_checkout_page...")

# Call the process_checkout_page function
# Using fast=True for quicker testing, set to False for more comprehensive (Gemini) analysis
# Set verbose=True to see detailed output during processing
API_KEYS = [
    "AIzaSyBszIBVzkBg92-WXkyer82lL7k63Kn9RFs",
    # "YOUR_SECOND_API_KEY_IF_TESTING_ROTATION",
    "AIzaSyBXZLvzTn2Jf52PZ_PgwDlNRtWUu37aPx4" 
    # "YOUR_THIRD_API_KEY_IF_TESTING_ROTATION"
]

results = process_checkout_page(
    html_content=sample_html,
    user_data=test_user_data,
    checkout_url="https://example.com/test-checkout", 
    verbose=False, 
    api_keys=API_KEYS, # List of API keys for rotation
    fast=True, # Using fast mode for a quick test
    depth=0, # Using the smallest Gemma model for speed in fast mode
    min_size_for_chunking=100, # Minimum size for chunking
    max_chunks=20, # Maximum number of chunks to process
    save_to_file=False # Avoids writing a file during this test
)

print("\n✅ Test completed.")
print("\n📄 Results:")
# Pretty print the JSON results
# print(json.dumps(results, indent=2))

# You can access specific parts of the result like so:
# print("\n🛒 Actions:")
# if results.get('actions'):
#     for action in results.get('actions'):
#         print(f"- {action.get('description')}: {action.get('value')}")
# else:
#     print("No actions generated or an error occurred.")
#     if results.get('validation_status') and not results['validation_status'].get('is_valid'):
#         print(f"Validation Error: {results['validation_status'].get('error_message')}")
# Out:
# 🧪 Running test for process_checkout_page...
# 🔑 Initialized with 2 API keys
# 🚀 Starting checkout form automation...
# ...
# 💨 Using fast mode with model: gemma-3-1b-it
# INFO: Attempting API call with key: AIzaS...9RFs (Attempt 1/30) in generate_content_with_model
# INFO: Attempting API call with key: AIzaS...9RFs (Attempt 1/30) in generate_content_with_model
# 🔍 Element detection summary:
#    - Total elements: 15
#    - Input-type elements: 11
#    - Button-type elements: 3
# INFO: Attempting API call with key: AIzaS...9RFs (Attempt 1/30) in generate_content_with_model
# 🔍 Element detection summary:
#    - Total elements: 15
#    - Input-type elements: 11
#    - Button-type elements: 3
# INFO: Attempting API call with key: AIzaS...9RFs (Attempt 1/30) in generate_content_with_model
# HTML size: 8.3 KB
# Chunking strategy: Enabled
# Max chunks: 20
# Using parallel processing with chunking...
# Processing 20 chunks with 4 workers
# Processing chunk 1/20 (size: 425 chars)
# ...

# %%
import google.generativeai as genai
import time
from itertools import cycle

# === CONFIGURE YOUR API KEYS BELOW ===
# Replace "YOUR_ACTUAL_API_KEY_HERE" with your valid Gemini API key.
# To test key rotation effectively, add multiple distinct API keys to this list.
API_KEYS = [
    "AIzaSyBszIBVzkBg92-WXkyer82lL7k63Kn9RFs",
    # "YOUR_SECOND_API_KEY_IF_TESTING_ROTATION",
    "AIzaSyBXZLvzTn2Jf52PZ_PgwDlNRtWUu37aPx4" 
    # "YOUR_THIRD_API_KEY_IF_TESTING_ROTATION"
]

NUM_REQUESTS = 15           # Total number of requests to test
DELAY_BETWEEN = 0.0         # Seconds between requests

def send_request(api_key, index):
    try:
        genai.configure(api_key=api_key)
        # Using gemini-2.5-flash-preview-05-20 as requested
        model = genai.GenerativeModel("gemini-2.5-flash-preview-05-20") 
        response = model.generate_content("Just say hello")
        print(f"[{index}] ✅ Success | Key: {api_key[:5]}... | Model: gemini-2.5-flash-preview-05-20 | Time: {time.strftime('%H:%M:%S')}")
        return True
    except Exception as e:
        print(f"[{index}] ❌ Error with key {api_key[:5]}... | {str(e)}")
        return False

# Ensure API_KEYS is not empty before proceeding
if not API_KEYS or API_KEYS[0] == "YOUR_ACTUAL_API_KEY_HERE":
    print("🛑 Please replace 'YOUR_ACTUAL_API_KEY_HERE' with your actual API key in the API_KEYS list.")
else:
    # === TEST 1: No Key Switching (uses the first key in the list) ===
    print("\n--- TEST 1: Without API Key Rotation (Using First Key) ---\n")
    # for i in range(NUM_REQUESTS):
    #     send_request(API_KEYS[0], i + 1)
    #     time.sleep(DELAY_BETWEEN)

    # === TEST 2: With API Key Switching ===
    # If only one key is provided, this will effectively use that single key repeatedly.
    # For true rotation testing, provide multiple distinct API keys in the API_KEYS list.
    print("\n--- TEST 2: With API Key Rotation ---\n")
    if len(API_KEYS) == 1:
        print("ℹ️ Only one API key provided. Rotation test will use this single key repeatedly.")
    
    rotating_keys = cycle(API_KEYS)
    for i in range(NUM_REQUESTS):
        api_key = next(rotating_keys)
        send_request(api_key, i + 1)
        time.sleep(DELAY_BETWEEN)
# Out:
# --- TEST 1: Without API Key Rotation (Using First Key) ---
#
#
# --- TEST 2: With API Key Rotation ---
#
# [1] ✅ Success | Key: AIzaS... | Model: gemini-2.5-flash-preview-05-20 | Time: 17:53:37
# [1] ✅ Success | Key: AIzaS... | Model: gemini-2.5-flash-preview-05-20 | Time: 17:53:37
# [2] ✅ Success | Key: AIzaS... | Model: gemini-2.5-flash-preview-05-20 | Time: 17:53:39
# [2] ✅ Success | Key: AIzaS... | Model: gemini-2.5-flash-preview-05-20 | Time: 17:53:39
# [3] ✅ Success | Key: AIzaS... | Model: gemini-2.5-flash-preview-05-20 | Time: 17:53:41
# [3] ✅ Success | Key: AIzaS... | Model: gemini-2.5-flash-preview-05-20 | Time: 17:53:41
# [4] ✅ Success | Key: AIzaS... | Model: gemini-2.5-flash-preview-05-20 | Time: 17:53:43
# [4] ✅ Success | Key: AIzaS... | Model: gemini-2.5-flash-preview-05-20 | Time: 17:53:43
# [5] ✅ Success | Key: AIzaS... | Model: gemini-2.5-flash-preview-05-20 | Time: 17:53:44
# [5] ✅ Success | Key: AIzaS... | Model: gemini-2.5-flash-preview-05-20 | Time: 17:53:44
# ...
